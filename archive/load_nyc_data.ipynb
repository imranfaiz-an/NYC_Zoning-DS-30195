# %%
from pathlib import Path

import geopandas as gpd

# File Geodatabase from NYC Planning — place `zoning.gdb` in this folder (or update the path).
gdb_path = Path.cwd() / "zoning2.gdb"

# List feature classes / layers (requires GDAL FileGDB driver; often via pyogrio/fiona).
layers = gpd.list_layers(gdb_path)
print(layers)
# Out:
#       name geometry_type
# 0     nyzd  MultiPolygon
# 1     nyco  MultiPolygon
# 2     nysp  MultiPolygon
# 3  nysp_sd  MultiPolygon
# 4     nylh  MultiPolygon
# 5    nyzma  MultiPolygon

# %%
# Read a layer by name (replace with the layer you need from the table above).
# Example: primary zoning districts layer — inspect `layers["name"]` for exact strings.
layer_name = layers.loc[0, "name"]
gdf = gpd.read_file(gdb_path, layer=layer_name)

gdf.head()
gdf.crs
# Out:
# <Projected CRS: EPSG:2263>
# Name: NAD83 / New York Long Island (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: United States (USA) - New York - counties of Bronx; Kings; Nassau; New York; Queens; Richmond; Suffolk.
# - bounds: (-74.26, 40.47, -71.8, 41.3)
# Coordinate Operation:
# - name: SPCS83 New York Long Island zone (US survey foot)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf.plot('ZONEDIST')
# Out:
# <Axes: >

# %%
gdf
# Out:
#      ZONEDIST  Shape_Length    Shape_Area  \
# 0         R7A  17623.566414  1.990866e+06
# 1        R4-1   2575.578630  3.722454e+05
# 2        PARK    569.651123  1.606990e+04
# 3        PARK    719.458367  2.017800e+04
# 4       C4-4D   1147.584820  7.561834e+04
# ...       ...           ...           ...
# 5399     M3-1   1709.151073  1.688653e+05
# 5400     M3-1   1905.776300  2.402738e+05
# 5401     R4-1   5768.785908  1.140818e+06
# 5402       R4   5453.720693  1.796626e+06
# 5403     M3-1   6044.958720  1.152914e+06
#
#                                                geometry
# 0     MULTIPOLYGON (((1020182.346 186031.923, 102020...
# 1     MULTIPOLYGON (((982158.973 167972.613, 981835....
# 2     MULTIPOLYGON (((996439.256 197691.699, 996350....
# 3     MULTIPOLYGON (((988123 179762.232, 988060.069 ...
# 4     MULTIPOLYGON (((1013228.549 184395.28, 1013238...
# ...                                                 ...
# 5399  MULTIPOLYGON (((1029111.984 217367.108, 102909...
# ...
